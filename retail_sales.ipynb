# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('retail_sales_dataset.csv', parse_dates=["Date"])

# %%
plt.rcParams["figure.figsize"] = (14, 8)

# %%
df.head()
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
sns.histplot(data=df, x="Product Category", hue="Gender")
# Out:
# <Axes: xlabel='Product Category', ylabel='Count'>

# %%
sns.barplot(data=df[df["Gender"] == "Female"], x="Product Category", y="Age",)
# Out:
# <Axes: xlabel='Product Category', ylabel='Age'>

# %%
df["day"] = df["Date"].dt.day
df["month"] = df["Date"].dt.month
df["year"] = df["Date"].dt.year

# %%
gender_w = df[df["Gender"] == "Female"]

# %%
gender_w.head()
# Out:
#     Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 1                2 2023-02-27     CUST002  Female   26         Clothing
# 5                6 2023-04-25     CUST006  Female   45           Beauty
# 9               10 2023-10-07     CUST010  Female   52         Clothing
# 14              15 2023-01-16     CUST015  Female   42      Electronics
# 16              17 2023-04-22     CUST017  Female   27         Clothing
#
#     Quantity  Price per Unit  Total Amount  day  month  year
# 1          2             500          1000   27      2  2023
# 5          1              30            30   25      4  2023
# 9          4              50           200    7     10  2023
# 14         4             500          2000   16      1  2023
# 16         4              25           100   22      4  2023

# %%
sns.barplot(data=gender_w, x="month", y="Total Amount", hue="Product Category")

# %%
gender_w["Total Amount"].describe()
# Out:
# count     510.000000
# mean      456.549020
# std       554.299371
# min        25.000000
# 25%        60.000000
# 50%       150.000000
# 75%       900.000000
# max      2000.000000
# Name: Total Amount, dtype: float64

# %%
sns.barplot(data=gender_w, x="day", y="Total Amount")
